# %%
import pandas as pd
import seaborn as sns

path = r"C:\\Users\\pc\\Desktop\\Università\\Data science\\Progetti\\ProgettoPython\\Dataset\\archive (1)\\csvs_per_year\\csvs_per_year\\"

# %%
allMadrid = pd.read_csv(path+"out.csv")
NO22018 = allMadrid['NO_2'].loc[allMadrid['date'] > '2018-01-01']
NO22017 = allMadrid['NO_2'].loc[(allMadrid['date'] < '2018-01-01')
                     & (allMadrid['date'] >= '2017-01-01')]

#display(NO22018.head())
test = pd.DataFrame({'NO_2':NO22018.values})
test2 = pd.DataFrame({'NO_2':NO22017.values})

penguins = sns.load_dataset("penguins")
sns.set_style("darkgrid")
sns.histplot(data=allMadrid, x="NO_2",kde=True,bins=30,stat="density",color='lightgreen')
#display(penguins)
# Out:
# <AxesSubplot: xlabel='NO_2', ylabel='Density'>

# %%
sns.set_style("darkgrid")
sns.histplot(data=allMadrid, x="NO",kde=True,bins=15,stat="density",color='orange')
# Out:
# <AxesSubplot: xlabel='NO', ylabel='Density'>

# %%
sns.set_style("darkgrid")
sns.histplot(data=allMadrid, x="SO_2",kde=True,bins=30,stat="density",color='yellow')
# Out:
# <AxesSubplot: xlabel='SO_2', ylabel='Density'>

# %%
sns.set_style("darkgrid")
sns.histplot(data=allMadrid, x="PM10",kde=True,bins=30,stat="density",color='blue')
# Out:
# <AxesSubplot: xlabel='PM10', ylabel='Density'>

# %%
sns.set_style("darkgrid")
sns.histplot(data=allMadrid, x="PM25",kde=True,bins=30,stat="density",color='red')
# Out:
# <AxesSubplot: xlabel='PM25', ylabel='Density'>

# %%
sns.set_style("darkgrid")
sns.histplot(data=allMadrid, x="O_3",kde=True,bins=30,stat="density",color='pink')
# Out:
# <AxesSubplot: xlabel='O_3', ylabel='Density'>
