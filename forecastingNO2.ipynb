# %% [markdown]
# # Forecasting

# %% [markdown]
# Importiamo le librerie necessarie e definiamo il path dove stanno i dataset

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels.api as sm
path = r".\\DataSet\\"
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
import sklearn.metrics as met

# %% [markdown]
# Apriamo il csv contenente i dati, convertiamo la data e raggruppiamo per giorno i risultati delle varie stazioni alle varie ore del giorno, facendone la media.

# %%
allMadrid = pd.read_csv(path+"out.csv")
allMadrid['date'] = pd.to_datetime(allMadrid['date'], format='%Y/%m/%d')
allMadrid['date']=allMadrid['date'].dt.normalize()
allMadrid=allMadrid.groupby(['date']).mean()
display(allMadrid)
# Out:
#                  BEN        CO       EBE      NMHC         NO       NO_2  \
# date
# 2008-01-01  1.314348  0.652554  1.040163  0.314783  11.820078  67.084565
# 2008-01-02  1.128177  0.531806  1.016719  0.270625  11.820078  66.552372
# 2008-01-03  0.727969  0.360000  0.942292  0.229083  11.820078  50.410930
# 2008-01-04  0.907969  0.458993  1.062031  0.257647  11.820078  58.247292
# 2008-01-05  0.823750  0.389635  0.785260  0.238250  11.820078  47.282292
# ...              ...       ...       ...       ...        ...        ...
# 2018-04-27  0.364583  0.249583  0.443750  0.062639   7.756522  26.074783
# 2018-04-28  0.216667  0.212917  0.194444  0.055000   2.824653  13.512153
# 2018-04-29  0.193750  0.218333  0.133333  0.053194   2.333333  11.098958
# 2018-04-30  0.263309  0.236250  0.166906  0.057500   4.557292  20.576389
# 2018-05-01  0.383333  0.250000  0.200000  0.060000   2.875000  29.125000
#
#                   O_3       PM10       PM25       SO_2       TCH       TOL  \
# date
# 2008-01-01   9.280977  39.855419  25.650870  19.815357  1.656304  4.026522
# 2008-01-02   9.750819  21.005401  15.767895  14.897970  1.536750  3.857708
# 2008-01-03  30.313847   9.173423   5.617396  10.923919  1.400333  2.911875
# 2008-01-04  20.756432  21.390939  13.236000  12.875144  1.409706  4.055104
# 2008-01-05  20.405407  18.745682  12.485729  11.804503  1.482792  3.244219
# ...               ...        ...        ...        ...       ...       ...
# 2018-04-27  65.695783  26.278317  10.256944   3.677966  1.340833  1.625000
# 2018-04-28  71.706587  10.971154   5.930556   3.604167  1.300556  0.691667
# 2018-04-29  78.044643   6.955128   3.229167   3.591667  1.289861  0.370833
# 2018-04-30  68.814925   6.862179   3.354167   3.800000  1.305694  0.603597
# 2018-05-01  56.357143   4.461538   2.666667   4.500000  1.323333  0.850000
#
#                  station
# date
# 2008-01-01  2.807902e+07
# 2008-01-02  2.807902e+07
# 2008-01-03  2.807902e+07
# 2008-01-04  2.807902e+07
# 2008-01-05  2.807902e+07
# ...                  ...
# 2018-04-27  2.807904e+07
# 2018-04-28  2.807904e+07
# 2018-04-29  2.807904e+07
# 2018-04-30  2.807904e+07
# 2018-05-01  2.807904e+07
#
# [3774 rows x 13 columns]

# %%
allMadrid.isnull().sum()
# Out:
# BEN        0
# CO         0
# EBE        0
# NMHC       0
# NO         0
# NO_2       0
# O_3        0
# PM10       0
# PM25       0
# SO_2       0
# TCH        0
# TOL        0
# station    0
# dtype: int64

# %% [markdown]
# ## NO2

# %% [markdown]
# Prendiamo i dati relativi al NO2 e stampiamo il suo andamento

# %%
forNo = allMadrid['NO_2']
forNo.plot(figsize=(15, 2))
# Out:
# <AxesSubplot: xlabel='date'>

# %% [markdown]
# ### Augmented dickey fuller test (Stazionarietà)

# %%
X2 = forNo.values
result2 = adfuller(X2)
print('ADF Statistic: %f' % result2[0])
print('p-value: %f' % result2[1])
print('Critical Values:')
for key, value in result2[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.235168
# p-value: 0.000007
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# ### Stagionalità, trend e residui

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
dec2 = seasonal_decompose(forNo, model='additive')
dec2.plot()
plt.show()

# %% [markdown]
# ### Autocorrelazione e Autocorrelazione parziale

# %%
sm.graphics.tsa.plot_pacf(forNo.values.squeeze(), lags=40, method="ywm")
plt.show()

# %%
sm.graphics.tsa.plot_acf(forNo.values.squeeze(), lags=40)
plt.show()

# %% [markdown]
# ### Modello per predizione

# %%
nobs = len(forNo)
n_init_training = int(nobs * 0.8)

# Creiamo il modello per il training
init_training_forNo = forNo[:n_init_training]
# fit ARIMA model
fig = plt.figure(figsize=(20,8))
model = ARIMA(init_training_forNo, seasonal_order=(2,2,4,12)) 
ax = plt.gca()
results_80 = model.fit() 
plt.plot(forNo)
plt.plot(results_80.fittedvalues, color='red')
ax.legend(['SO_2', 'Forecast'])

print(results_80.summary())
print("Il numero degli elementi del periodo considerato è: "+str(nobs))
print("L'indice dell'ultimo elemento del training set è: "+str(n_init_training))

# %%
last_period=forNo['2011-06-01':]
nobs_last = len(last_period)
n_init_training_last = int(nobs_last * 0.8)

# Creiamo il modello per il training
init_training_last = last_period[:n_init_training_last]
# fit ARIMA model
fig = plt.figure(figsize=(20,8))
model_last = ARIMA(init_training_last, order=(3,0,1), seasonal_order=(0,0,1,12)) 
ax = plt.gca()
results_last = model_last.fit() 
plt.plot(forNo, color='g')
plt.plot(last_period, color='b')
plt.plot(results_last.fittedvalues, color='red')
ax.legend(['SO_2', 'Training Set','Forecast'])

print(results_last.summary())
print("Il numero degli elementi del periodo considerato è: "+str(nobs_last))
print("L'indice dell'ultimo elemento del training set è: "+str(n_init_training_last))
# Out:
# d:\Program Files\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# d:\Program Files\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# d:\Program Files\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                     SARIMAX Results
# ========================================================================================
# Dep. Variable:                             NO_2   No. Observations:                 2021
# Model:             ARIMA(3, 0, 1)x(0, 0, 1, 12)   Log Likelihood               -7717.349
# Date:                          Thu, 01 Dec 2022   AIC                          15448.698
# Time:                                  13:19:15   BIC                          15487.978
# Sample:                              06-01-2011   HQIC                         15463.113
#                                    - 12-11-2016
# Covariance Type:                            opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         38.0315      2.752     13.822      0.000      32.639      43.424
# ar.L1          1.6018      0.027     60.305      0.000       1.550       1.654
# ar.L2         -0.7886      0.035    -22.501      0.000      -0.857      -0.720
# ar.L3          0.1773      0.020      8.712      0.000       0.137       0.217
# ma.L1         -0.8840      0.019    -47.279      0.000      -0.921      -0.847
# ma.S.L12      -0.1218      0.022     -5.414      0.000      -0.166      -0.078
# sigma2       121.3457      3.599     33.715      0.000     114.291     128.400
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                19.31
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.87   Skew:                             0.16
# Prob(H) (two-sided):                  0.07   Kurtosis:                         3.36
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Il numero degli elementi del periodo considerato è: 2527
# L'indice dell'ultimo elemento del training set è: 2021

# %% [markdown]
# ### Predizione in-sample

# %%
fig = plt.figure(figsize=(20,8))
x2 = results_80.get_prediction(start=(n_init_training+1), end=(nobs-1)).summary_frame()

plt.plot(init_training_forNo[2400:], color='g')
plt.plot(forNo[n_init_training+1:],color='b')
plt.plot(x2['mean'], color='r')
plt.legend([ 'Training Set','Test Set', 'Forecast'])
plt.fill_between(x2.index, x2['mean_ci_lower'], x2['mean_ci_upper'], color='k', alpha=0.1)

# %%
fig = plt.figure(figsize=(20,8))
x_last = results_last.get_prediction(start=(n_init_training_last+1), end=(nobs_last-1)).summary_frame()

plt.plot(init_training_last['2014-07-01':], color='g')
plt.plot(forNo[n_init_training_last+1:],color='b')
plt.plot(x_last['mean'], color='r')
plt.legend([ 'Training Set','Test Set', 'Forecast'])
plt.fill_between(x_last.index, x_last['mean_ci_lower'], x_last['mean_ci_upper'], color='k', alpha=0.1)

# %% [markdown]
# Metriche valutazione della predizione in-sample

# %%
Y_actual2 = forNo[n_init_training+1:]
Y_Predicted2 = x2['mean']
mape2 = met.mean_absolute_percentage_error(Y_actual2, Y_Predicted2)
print(mape2)

# %%
Y_actual_last = last_period[n_init_training_last+1:]
Y_Predicted_last = x_last['mean']
mape_last = met.mean_absolute_percentage_error(Y_actual_last, Y_Predicted_last)
print(mape_last)
# Out:
# 0.4225694696705674

# %%
sqe=met.mean_squared_error(Y_actual2, Y_Predicted2)
print(sqe)

# %%
sqe_last=met.mean_squared_error(Y_actual_last, Y_Predicted_last)
print(sqe_last)
# Out:
# 339.95605846499086

# %%
mae = met.mean_absolute_error(Y_actual2, Y_Predicted2)
print(mae)

# %%
mae_last = met.mean_absolute_error(Y_actual_last, Y_Predicted_last)
print(mae_last)
# Out:
# 14.430321612899775

# %%
r2_last = met.r2_score(Y_actual_last, Y_Predicted_last)
print(r2_last)
# Out:
# 0.00876134455358657

# %% [markdown]
# ### Predizione out-sample

# %%
fig3, ax3 = plt.subplots(figsize=(15, 5))

# Plot the data (here we are subsetting it to get a better look at the forecasts)
forNo['2017-12-01':].plot(ax=ax3)

# Construct the forecasts
fcast = results_80.get_prediction(start=(nobs), end=(nobs+60)).summary_frame()
fcast['mean'].plot(ax=ax3, style='k--')
ax3.fill_between(fcast.index, fcast['mean_ci_lower'], fcast['mean_ci_upper'], color='k', alpha=0.1)

# %%
fig3, ax3 = plt.subplots(figsize=(15, 5))

# Plot the data (here we are subsetting it to get a better look at the forecasts)
forNo['2017-12-01':].plot(ax=ax3)

# Construct the forecasts
fcast_last = results_last.get_prediction(start=(nobs_last), end=(nobs_last+60)).summary_frame()
fcast_last['mean'].plot(ax=ax3, style='k--')
ax3.fill_between(fcast_last.index, fcast_last['mean_ci_lower'], fcast_last['mean_ci_upper'], color='k', alpha=0.1)

# %% [markdown]
# ## Prova con autoarima

# %%
from pmdarima.arima import auto_arima

last_period=forNo['2011-06-01':]
nobs_last = len(last_period)
n_init_training_last = int(nobs_last * 0.8)

# Creiamo il modello per il training
init_training_last = last_period[:n_init_training_last]

model_auto = auto_arima(init_training_last, start_p=1, start_q=1,
                      test='adf',
                      max_p=10, max_q=10,
                      m=12,                       
                      seasonal=True,   
                      start_P=0, 
                      D=None, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=15597.818, Time=1.70 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=17135.987, Time=0.06 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=15602.180, Time=2.01 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=16006.413, Time=1.62 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=20803.245, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=15600.307, Time=0.53 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=15598.223, Time=4.49 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=15596.527, Time=4.38 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=15591.716, Time=12.41 sec
#  ARIMA(1,0,1)(2,0,2)[12] intercept   : AIC=15590.000, Time=10.98 sec
#  ARIMA(1,0,1)(2,0,1)[12] intercept   : AIC=15593.128, Time=10.98 sec
#  ARIMA(0,0,1)(2,0,2)[12] intercept   : AIC=15966.205, Time=11.33 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=11.02 sec
#  ARIMA(2,0,1)(2,0,2)[12] intercept   : AIC=15582.926, Time=12.44 sec
#  ARIMA(2,0,1)(1,0,2)[12] intercept   : AIC=15584.933, Time=12.67 sec
#  ARIMA(2,0,1)(2,0,1)[12] intercept   : AIC=15586.309, Time=11.54 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=15593.308, Time=4.79 sec
#  ARIMA(2,0,0)(2,0,2)[12] intercept   : AIC=15592.745, Time=12.08 sec
#  ARIMA(3,0,1)(2,0,2)[12] intercept   : AIC=15587.118, Time=15.32 sec
#  ARIMA(2,0,2)(2,0,2)[12] intercept   : AIC=15591.034, Time=17.30 sec
#  ARIMA(1,0,2)(2,0,2)[12] intercept   : AIC=inf, Time=16.59 sec
#  ARIMA(3,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=18.66 sec
#  ARIMA(3,0,2)(2,0,2)[12] intercept   : AIC=15578.448, Time=24.92 sec
#  ARIMA(3,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=19.38 sec
#  ARIMA(3,0,2)(2,0,1)[12] intercept   : AIC=15566.008, Time=17.70 sec
#  ARIMA(3,0,2)(1,0,1)[12] intercept   : AIC=15574.295, Time=8.72 sec
#  ARIMA(3,0,2)(2,0,0)[12] intercept   : AIC=15503.673, Time=16.43 sec
#  ARIMA(3,0,2)(1,0,0)[12] intercept   : AIC=15475.828, Time=6.97 sec
#  ARIMA(3,0,2)(0,0,0)[12] intercept   : AIC=15477.663, Time=2.86 sec
#  ARIMA(3,0,2)(0,0,1)[12] intercept   : AIC=15453.607, Time=7.19 sec
#  ARIMA(3,0,2)(0,0,2)[12] intercept   : AIC=15458.969, Time=16.10 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=15450.510, Time=6.28 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=15473.312, Time=2.74 sec
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=15599.506, Time=6.99 sec
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=15452.330, Time=14.63 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=15458.162, Time=6.11 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=15533.038, Time=16.60 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=15496.844, Time=4.08 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=15589.031, Time=4.86 sec
#  ARIMA(2,0,3)(0,0,1)[12] intercept   : AIC=15452.275, Time=5.79 sec
#  ARIMA(1,0,3)(0,0,1)[12] intercept   : AIC=15451.436, Time=4.17 sec
#  ARIMA(3,0,1)(0,0,1)[12] intercept   : AIC=15448.779, Time=5.69 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=15476.000, Time=2.42 sec
#  ARIMA(3,0,1)(1,0,1)[12] intercept   : AIC=15554.383, Time=7.55 sec
#  ARIMA(3,0,1)(0,0,2)[12] intercept   : AIC=15455.270, Time=12.61 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : AIC=15481.090, Time=7.16 sec
#  ARIMA(3,0,1)(1,0,2)[12] intercept   : AIC=15527.952, Time=14.16 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=15555.590, Time=2.64 sec
#  ARIMA(4,0,1)(0,0,1)[12] intercept   : AIC=15453.644, Time=5.99 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=15600.413, Time=1.56 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=15539.241, Time=2.43 sec
#  ARIMA(4,0,2)(0,0,1)[12] intercept   : AIC=inf, Time=6.68 sec
#  ARIMA(3,0,1)(0,0,1)[12]             : AIC=15463.045, Time=2.04 sec
#
# Best model:  ARIMA(3,0,1)(0,0,1)[12] intercept
# Total fit time: 457.026 seconds
